# %%
from datetime import datetime, timedelta
import glob
import time
import numpy as np
import talib

# from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

import plotly as py
import cufflinks as cf
import pandas as pd
import plotly.tools as tls
import plotly.graph_objs as go

import plotly.figure_factory as ff
init_notebook_mode(connected=True)

import pyodbc
from sqlalchemy import create_engine


#  todo driver 修正
def conn():
    return pyodbc.connect(
        'DRIVER={ODBC Driver 13 for SQL Server};' + 'SERVER=localhost;' +
        'PORT=1443;' + 'DATABASE=StockDB;' + 'UID=sa;' + 'PWD=admin;')


# Create the sqlalchemy engine using the pyodbc connection
engine = create_engine(
    "mssql+pyodbc://?driver=ODBC+Driver+13?charset=utf8", creator=conn)
con = engine.connect()
con.execute("SET LANGUAGE us_english; set dateformat ymd;")
con.close()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
query_num = '2330'

# %%
cmd = """SELECT
      [date],
      [close_price],
      [open_price]
      FROM [dbo].[TECH_M] WHERE stock = \'{}\' ORDER BY date DESC"""

tech_m_df = pd.read_sql_query( cmd.format(query_num), engine )

tech_m_df[ 'date' ] = pd.to_datetime( tech_m_df[ 'date' ], format='%Y-%m-%d' )

# tech_m_df

# %%
import warnings

cmd = """SELECT
      [date]
      ,[Month_Revenue]
      ,[Last_Month_Revenue]
      ,[Last_Year_Revenue]
      ,[Last_Month_Ratio]
      ,[Last_Year_Ration]
      ,[Month_Acc_Revenue]
      ,[Last_Year_Acc_Revenue]
      ,[ration]
  FROM [dbo].[REVENUE] WHERE stock = \'{}\' ORDER BY date DESC"""

revenue_df = pd.read_sql_query( cmd.format(query_num), engine )

revenue_df[ 'date' ] = pd.to_datetime( revenue_df[ 'date' ], format='%Y-%m-%d' )

revenue_df[ 'history_revenue_03' ] = revenue_df[ 'Month_Revenue' ].shift( 12*1 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*2 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*3 )

revenue_df[ 'history_revenue_03' ] = revenue_df[ 'history_revenue_03' ].shift( -12*4 )

revenue_df[ 'history_revenue_03' ] = revenue_df[ 'history_revenue_03' ] / 3

revenue_df[ 'history_revenue_03%' ] = ( revenue_df[ 'Month_Revenue' ] - revenue_df[ 'history_revenue_03' ] ) / revenue_df[ 'history_revenue_03' ] * 100 
# -------------------------

revenue_df[ 'history_revenue_05' ] = revenue_df[ 'Month_Revenue' ].shift( 12*1 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*2 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*3 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*4 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*5 )

revenue_df[ 'history_revenue_05' ] = revenue_df[ 'history_revenue_05' ].shift( -12*6 )

revenue_df[ 'history_revenue_05' ] = revenue_df[ 'history_revenue_05' ] / 5 

revenue_df[ 'history_revenue_05%' ] = ( revenue_df[ 'Month_Revenue' ] - revenue_df[ 'history_revenue_05' ] ) / revenue_df[ 'history_revenue_05' ] * 100

# -------------------------

revenue_df[ 'history_revenue_08' ] = revenue_df[ 'Month_Revenue' ].shift( 12*1 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*2 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*3 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*4 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*5 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*6 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*7 ) + \
                                     revenue_df[ 'Month_Revenue' ].shift( 12*8 )                        
                        
revenue_df[ 'history_revenue_08' ] = revenue_df[ 'history_revenue_08' ].shift( -12*9 )

revenue_df[ 'history_revenue_08' ] = revenue_df[ 'history_revenue_08' ] / 8 

revenue_df[ 'history_revenue_08%' ] = ( revenue_df[ 'Month_Revenue' ] - revenue_df[ 'history_revenue_08' ] ) / revenue_df[ 'history_revenue_08' ] * 100

revenue_df[ [ 'date', 'history_revenue_03%', 'history_revenue_05%', 'history_revenue_08%' ] ].head( 48 )

# -------------------------

revenue_df[ 'history_revenue_01' ] = revenue_df[ 'Month_Revenue' ].shift( 12*1 )

revenue_df[ 'history_revenue_01' ] = revenue_df[ 'history_revenue_01' ].shift( -12*2 )

revenue_df[ 'history_revenue_01%' ] = ( revenue_df[ 'Month_Revenue' ] - revenue_df[ 'history_revenue_01' ] ) / revenue_df[ 'history_revenue_01' ] * 100

# -------------------------

warnings.filterwarnings( "ignore", category=RuntimeWarning )

revenue_df[ 'history_revenue_01%' ] = revenue_df[ 'history_revenue_01%' ].round( 1 )

revenue_df[ 'history_revenue_03%' ] = revenue_df[ 'history_revenue_03%' ].round( 1 )

revenue_df[ 'history_revenue_05%' ] = revenue_df[ 'history_revenue_05%' ].round( 1 )

revenue_df[ 'history_revenue_08%' ] = revenue_df[ 'history_revenue_08%' ].round( 1 )


# revenue_df[ [ 'date', 'history_revenue_01%', 'history_revenue_03%', 'history_revenue_05%', 'history_revenue_08%' ] ].head( 48 )

# %%
revenue_df.sort_values( by = 'date', inplace = True )

tech_m_df.sort_values( by = 'date', inplace = True )

result = pd.merge_asof( revenue_df, tech_m_df, on='date', direction='nearest' )

result = result[ ::-1 ]

# result

# %%
trace1 = go.Scatter(
    x = result[ 'date' ],
    y = result[ 'history_revenue_01%' ],
    mode = 'lines',
    name = '較前年當月營收成長%',
    line = dict( width = 1 )
)

trace2 = go.Scatter(
    x = result[ 'date' ],
    y = result[ 'history_revenue_03%' ],
    mode = 'lines',
    name = '較前3年當月營收成長%',
    line = dict( width = 1 )
)

trace3 = go.Scatter(
    x = result[ 'date' ],
    y = result[ 'history_revenue_05%' ],
    mode = 'lines',
    name = '較前5年當月營收成長%',
    line = dict( width = 1 )
)

trace4 = go.Scatter(
    x = result[ 'date' ],
    y = result[ 'history_revenue_08%' ],
    mode = 'lines',
    name = '較前8年當月營收成長%',
    line = dict( width = 1 )
)

trace5 = go.Scatter(
    x = result[ 'date' ],
    y = result[ 'open_price' ],
    mode = 'lines',
    name = 'open_price',
    line = dict( width = 2 ),
    yaxis='y2'
)

data = [ trace1, trace2, trace3, trace4, trace5 ]

layout = go.Layout(
    
    title='{} 營收'.format( query_num ),
    
    yaxis=dict(
        title='營收成長'
    ),
    
    yaxis2 = dict(
        
        title='股價',
        
        overlaying='y',
        side='right'
    )
)

fig = go.Figure( data=data, layout=layout )

py.offline.iplot( fig, filename='ohlc_datetime' )
# Out:
# <div id="fb2e495b-66c9-4c37-84d3-77c8965e56c4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f
null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "mode": "lines", "type": "scatter", "x": ["2018-03-15", "2018-02-15", "2018-01-15", "2017-12-15", "2017-11-15", "2017-10-15", "2017-09-15", "2017-08-15", "2017-07-15", "2017-06-15", "2017-05-15", "2017-04-15", "2017-03-15", "2017-02-15", "2017-01-15", "2016-12-15", "2016-11-15", "2016-10-15", "2016-09-15", "2016-08-15", "2016-07-15", "2016-06-15", "2016-05-15", "2016-04-15", "2016-03-15", "2016-02-15", "2016-01-15", "2015-12-15", "2015-11-15", "2015-10-15", "2015-09-15", "2015-08-15", "2015-07-15", "2015-06-15", "2015-05-15", "2015-04-15", "2015-03-15", "2015-02-15", "2015-01-15", "2014-12-15", "2014-11-15", "2014-10-15", "2014-09-15", "2014-08-15", "2014-07-15", "2014-06-15", "2014-05-15", "2014-04-15", "2014-03-15", "2014-02-15", "2014-01-15", "2013-12-15", "2013-11-15", "2013-10-15", "2013-09-15", "2013-08-15", "2013-07-15", "2013-06-15", "2013-05-15", "2013-04-15", "2013-03-15", "2013-02-15", "2013-01-15", "2012-12-15", "2012-11-15", "2012-10-15", ...

# %%
cmd = """SELECT
      [date],
      [open_price],
      [high_price],
      [low_price],
      [close_price],
      [volume],
      [ma3],
      [ma10], 
      [ma60],
      [ma120],
      [ma240] FROM [dbo].[TECH_D] WHERE stock = \'{}\' ORDER BY date DESC"""

tech_d_df = pd.read_sql_query(cmd.format(query_num), engine)

# tech_d_df.head( )

tech_d_df['date'] = pd.to_datetime(tech_d_df['date'])

mask = (tech_d_df['date'] > '2017-1-1')

tech_d_df = tech_d_df.loc[mask]

trace0 = go.Candlestick( x   = tech_d_df[ 'date' ],
                       open  = tech_d_df[ 'open_price' ],
                       high  = tech_d_df[ 'high_price' ],
                       low   = tech_d_df[ 'low_price' ],
                       close = tech_d_df[ 'close_price' ],
                       name = 'K線',
                       line = dict( width = 1 ) )

trace1 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'ma3' ],
    mode = 'lines',
    name = '3日均線',
    line = dict( width = 1 )
)

trace2 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'ma10' ],
    mode = 'lines',
    name = '10日均線',
    line = dict( width = 1 )
)

trace3 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'ma60' ],
    mode = 'lines',
    name = '60日均線',
    line = dict( width = 1, color='rgb(82, 82, 82)' )
)

trace4 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'ma120' ],
    mode = 'lines',
    name = '120日均線',
    line = dict( width = 1 )
)

trace5 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'ma240' ],
    mode = 'lines',
    name = '240日均線',
    line = dict( width = 1 )
)

data = [ trace0, trace1, trace2, trace3, trace4, trace5 ]

py.offline.iplot( data, filename='ohlc_datetime')

# layout = {
#     'title': query_num,
#     'yaxis': { 'title': '股價' } }
# fig = dict( data = [trace], layout = layout )
# py.offline.iplot( fig, filename='ohlc_datetime')
# Out:
# <div id="c29291c8-89be-4c62-be13-9fa04a67d9c2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c29291c8-89be-4c62-be13-9fa04a67d9c2", [{"close": [223.5, 226.5, 230.5, 230.5, 233.0, 233.0, 229.5, 229.5, 228.0, 223.5, 223.0, 220.5, 223.0, 227.0, 223.5, 222.0, 225.0, 227.0, 226.5, 229.0, 244.5, 238.0, 238.0, 243.5, 244.5, 245.0, 248.0, 245.5, 245.0, 244.0, 246.5, 247.5, 246.0, 244.0, 245.0, 251.0, 243.5, 245.0, 251.5, 252.5, 253.0, 255.0
232.5, 230.5, 229.0, 228.5, 223.5, 221.5, 220.5, 220.0, 222.5, 222.5, 221.0, 221.0, 224.0, 225.0, 225.0, 228.0, 241.0, 236.5, 237.5, 242.0, 244.0, 244.0, 246.5, 243.5, 243.5, 242.0, 245.0, 246.5, 246.0, 242.5, 244.0, 247.0, 241.5, 244.0, 249.5, 251.0, 251.5, 251.0, 249.5, 255.0, 255.5, 255.0, 251.5, 248.5, 249.0, 246.0, 245.5, 240.5, 238.5, 242.0, 246.0, 245.0, 241.0, 239.0, 242.0, 235.0, 228.5, 238.0, 239.5, 234.0, 250.5, 255.0, 257.0, 252.0, 252.5, 255.0, 253.5, 256.5, 256.5, 262.5, 257.0, 251.5, 245.0, 239.0, 238.0, 238.0, 233.5, 232.5, 236.0, 239.5, 240.5, 238.0, 236.5, 235.5, 231.0, 226.5, 225.0, 225.0, 225.0, 226.5, 224.0, 224.5, 223.5, 224.0, 226.5, 226.5, 227.5, 226.5, 225.0, 227.0, 224.5, 222.5, 226.5, 228.5, 231.0, 227.5, 226.0, 234.5, 233.0, 237.0, 241.5, 241.5, 242.0, 239.5, 238.0, 240.5, 237.5, 236.0, 239.0, 239.5, 239.5, 240.0, 242.0, 241.5, 239.0, 238.5, 240.5, 241.5, 241.5, 241.5, 237.5, 236.0, 237.5, 238.0, 238.5, 237.5, 239.0, 237.0, 235.0, 236.0, 234.5, 234.5, 226.5, 223.5, 222.0, 219.0, 218.5, 216.5, 215.5, 213.5, 215.0, 214.0, 217.0, 218.5, 220.0, 220.0, 220.0, 218.0, 217.0, 217.5, 217.5, 217.5, 216.5, 216.5, 216.0, 216.0, 216.5, 215.5, 215.0, 215.5, 216.0, 215.0, 215.0, 216.0, 215.5, 214.0, 213.0, 211.5, 211.0, 213.0, 211.0, 213.0, 210.0, 21 ...

# %%
C = np.array( tech_d_df[ 'volume' ], dtype = float, ndmin = 1 )

for val in [ 5, 10, 20 ]:
    tech_d_df[ 'MA' + str( val ) ] = talib.SMA( C, val )

trace1 = go.Bar(
    
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'volume' ],
    name = '成交量',
    
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5,
        )
    ),
    
    opacity=0.6
)

trace2 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'MA5' ],
    mode = 'lines',
    name = '成交均線5',
    line = dict( width = 1 )
)

trace3 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'MA10' ],
    mode = 'lines',
    name = '成交均線10',
    line = dict( width = 1 )
)

trace4 = go.Scatter(
    x = tech_d_df[ 'date' ],
    y = tech_d_df[ 'MA20' ],
    mode = 'lines',
    name = '成交均線20',
    line = dict( width = 1 )
)

data = [ trace1, trace2, trace3, trace4 ]

py.offline.iplot( data, filename='ohlc_datetime')
# Out:
# <div id="be25b525-e6a5-4d44-8d0b-17696a0bf2a4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("be25b525-e6a5-4d44-8d0b-17696a0bf2a4", [{"marker": {"color": "rgb(158,202,225)", "line": {"color": "rgb(8,48,107)", "width": 1.5}}, "type": "bar", "x": ["2018-05-18", "2018-05-17", "2018-05-16", "2018-05-15", "2018-05-14", "2018-05-11", "2018-05-10", "2018-05-09", "2018-05-08", "2018-05-07", "2018-05-04", "2018-05-03", "2018-05-02", "2018-04-30", "2018-04-27", "2018-04-26", "2018-04-25", "2018-04-24", "2018-04-23", "2018-04-20", "2018-04-19", "2018-04-18", "2018-04-17", "2018-04-16", "2018-04-13", "2018-04-12", "2018-04-11", "2018-04-10", "2018-04-09", "2018-04-03", "2018-04-02", "2018-03-31", "2018-03-30", "2018-03-29", "2018-03-28", "2018-03-27", "2018-03-26", "2018-03-23", "2018-03-22", "2018-03-21", "2018-03-20", "2018-03-19", "2018-03-16", "2018-03-15", "2018-03-14", "2018-03-13", "2018-03-12", "2018-03-09", "2018-03-08", "2018-03-07", "2018-03-06", "2018-03-05", "2018-03-02", "2018-03-01", "2018-02-27", "2018-02-26", "2018-02-23", "2018-02-22", "2018-02-21", "2018-02-12", "2018-02-09", "2018-02-08", "2018-02-07", "2018-02-06", "2018-02-05", "2018-02-02", "2018-02-01", "2018-01-31", "2018-01-30", "2018-01-29", "2018-01-26", "2018-01-25", "2018-01-24", "2018-01-23", "2018-01-22", "2018-01-19", "2018-01-18", "2018-01-17", "2018-01-16", "2018-01-15", "2018-01-12", "2018-01-11", "2018-01-10", "2018-01-09", "2018-01-08", "2018-01-05", "2018-01-04", "2018-01-03", "2018-01-02", "2017-12-29", "2017-12-28", "2017-12-27", "2017-12-26", "2017-12-25", "2017-12-22", "2017-12-21", "2017-12-20", "2017-12-19", "2017-12-18", "2017-12-15", "2017-12-14", "2017-12-13", "2017-12-12", "2017-12-11", "2017-12-08", "2017-12-07", "2017-12-06", "2017-12-05", "2017-12-04", "2017-12-01", "2017-11-30", "2017-11-29", "2017-11-28", "2017-11-27", "2017-11-24", "2017-11-23", "2017-11-22", "2017-11-21", "2017-11-20", "2017-11-17", "2017-11-16", "2017-11-15", "2017-11-14", "2017-11-13", "2017-11-10", "2017-11-09", "2017-11-08", "2017-11-07", "2017-11-06", "2017-11-03", "2017-11-02", "2017-11-01", "2017-10-31", "2017-10-30", "2017-10-27", "2017-10-26", "2017-10-25", "2017-10-24", "2017-10-23", "2017-10-20", "2017-10-19", "2017-10-18", "2017-10-17", "2017-10-16", "2017-10-13", "2017-10-12", "2017-10-11", "2017-10-06", "2017-10-05", "2017-10-03", "2017-10-02", "2017-09-30", "2017-09-29", "2017-09-28", "2017-09-27", "2017-09-26", "2017-09-25", "2017-09-22", "2017-09-21", "2017-09-20", "2017-09-19", "2017-09-18", "2017-09-15", "2017-09-14", "2017-09-13", "2017-09-12", "2017-09-11", "2017-09-08", "2017-09-07", "2017-09-06", "2017-09-05", "2017-09-04", "2017-09-01", "2017-08-31", "2017-08-30", "2017-08-29", "2017-08-28", "2017-08-25", "2017-08-24", "2017-08-23", "2017-08-22", "2017-08-21", "2017-08-18", "2017-08-17", "2017-08-16", "2017-08-15", "2017-08-14", "2017-08-11", "2017-08-10", "2017-08-09", "2017-08-08", "2017-08-07", "2017-08-04", "2017-08-03", "2017-08-02", "2017-08-01", "2017-07-31", "2017-07-28", "2017-07-27", "2017-07-26", "2017-07-25", "2017-07-24", "2017-07-21", "2017-07-20", "2017-07-19", "2017-07-18", "2017-07-17", "2017-07-14", "2017-07-13", "2017-07-12", "2017-07-11", "2017-07-10", "2017-07-07", "2017-07-06", "2017-07-05", "2017-07-04", "2017-07-03", "2017-06-30", "2017-06-29", "2017-06-28", "2017-06-27", "2017-06-26", "2017-06-23", "2017-06-22", "2017-06-21", "2017-06-20", "2017-06-19", "2017-06-16", "2017-06-15", "2017-06-14", "2017-06-13", "2017-06-12", "2017-06-09", "2017-06-08", "2017-06-07", "2017-06-06", "2017-06-05", "2017-06-03", "2017-06-02", "2017-06-01", "2017-05-31", "2017-05-26", "2017-05-25", "2017-05-24", "2017-05-23", "2017-05-22", "2017-05-19", "2017-05-18", "2017-05-17", "2017-05-16", "2017-05-15", "2017-05-12", "2017-05-11", "2017-05-10", "2017-0 ...

# %%
# 外資
# 投信
# 自營商

cmd = """SELECT [stock]
      ,[date]
      ,[foreign_sell]
      ,[investment_sell]
      ,[dealer_sell]
      ,[single_day_sell]
      ,[foreign_estimate]
      ,[investment_estimate]
      ,[dealer_estimate]
      ,[single_day_estimate]
      ,[foreign_ratio]
      ,[investment_ratio]
  FROM [dbo].[INVESTORS]
  WHERE stock = \'{}\' ORDER BY date DESC"""
  
investors_df = pd.read_sql_query( cmd.format( query_num ), engine )

color = np.array( ['rgb(255,255,255)'] * investors_df[ 'foreign_sell' ].shape[ 0 ] )
color[ investors_df[ 'foreign_sell' ] < 0 ] = '#5fba7d'
color[ investors_df[ 'foreign_sell' ] > 0 ] = '#d65f5f'

trace1 = go.Bar(
    
    x = investors_df[ 'date' ],
    y = investors_df[ 'foreign_sell' ],
    
    name = '外資',
    
    marker=dict(
        color= color.tolist( ),
        line = dict(
            color = color.tolist( ),
            width=1,
        )
    ),
    
    opacity = 0.6
)

trace2 = go.Scatter(
    x = investors_df[ 'date' ],
    y = investors_df[ 'foreign_estimate' ],
    mode = 'lines',
    name = '外資累計',
    line = dict( width = 1 ),
    yaxis='y2'
)

data = [ trace1, trace2 ]

layout = go.Layout(
    
    title='外資買賣超',
    
    yaxis=dict(
        title='單日買賣量'
    ),
    
    yaxis2 = dict(
        title='累計買賣量',
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot( fig, filename='ohlc_datetime' )

# table = ff.create_table( investors_df.head( ) )
# py.offline.iplot( table, filename='jupyter-table1' )
# investors_df.head( )
# Out:
# <div id="6e79e517-873f-4e7d-8a74-19fd827928c0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6e79e517-873f-4e7d-8a74-19fd827928c0", [{"marker": {"color": ["#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f"], "line": {"color": ["#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d6 ...

# %%
color = np.array( ['rgb(255,255,255)'] * investors_df[ 'investment_sell' ].shape[ 0 ] )
color[ investors_df[ 'investment_sell' ] < 0 ] = '#5fba7d'
color[ investors_df[ 'investment_sell' ] > 0 ] = '#d65f5f'

trace1 = go.Bar(
    
    x = investors_df[ 'date' ],
    y = investors_df[ 'investment_sell' ],
    
    name = '投信',
    
    marker=dict(
        color= color.tolist( ),
        line = dict(
            color = color.tolist( ),
            width=1,
        )
    ),
    
    opacity = 0.6
)

trace2 = go.Scatter(
    x = investors_df[ 'date' ],
    y = investors_df[ 'investment_estimate' ],
    mode = 'lines',
    name = '投信累計',
    line = dict( width = 1 ),
    yaxis='y2'
)

data = [ trace1, trace2 ]

layout = go.Layout(
    
    title='投信買賣超',
    
    yaxis=dict(
        title='單日買賣量'
    ),
    
    yaxis2 = dict(
        title='累計買賣量',
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot( fig, filename='ohlc_datetime' )
# Out:
# <div id="a31b6100-e746-4c50-aeae-21b0b3a3e979" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a31b6100-e746-4c50-aeae-21b0b3a3e979", [{"marker": {"color": ["#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "rgb(255,255,255)", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d"], "line": {"color": ["#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", ...

# %%
color = np.array( ['rgb(255,255,255)'] * investors_df[ 'dealer_sell' ].shape[ 0 ] )
color[ investors_df[ 'dealer_sell' ] < 0 ] = '#5fba7d'
color[ investors_df[ 'dealer_sell' ] > 0 ] = '#d65f5f'

trace1 = go.Bar(
    
    x = investors_df[ 'date' ],
    y = investors_df[ 'dealer_sell' ],
    
    name = '自營商',
    
    marker=dict(
        color= color.tolist( ),
        line = dict(
            color = color.tolist( ),
            width=1,
        )
    ),
    
    opacity = 0.6
)

trace2 = go.Scatter(
    x = investors_df[ 'date' ],
    y = investors_df[ 'dealer_estimate' ],
    mode = 'lines',
    name = '自營商累計',
    line = dict( width = 1 ),
    yaxis='y2'
)

data = [ trace1, trace2 ]

layout = go.Layout(
    
    title='自營商買賣超',
    
    yaxis=dict(
        title='單日買賣量'
    ),
    
    yaxis2 = dict(
        title='累計買賣量',
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

fig = go.Figure(data=data, layout=layout)

py.offline.iplot( fig, filename='ohlc_datetime' )
# Out:
# <div id="5078b89f-1576-47fe-85b8-c272b6ec4f93" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5078b89f-1576-47fe-85b8-c272b6ec4f93", [{"marker": {"color": ["#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d"], "line": {"color": ["#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d ...

# %%
cmd = """SELECT [stock]
      ,[date]
      ,[Financing_Buy]
      ,[Financing_Sell]
      ,[Financing_PayOff]
      ,[Financing_Over]
      ,[Financing_Increase]
      ,[Financing_Limit]
      ,[Financing_Use]
      ,[Margin_Sell]
      ,[Margin_Buy]
      ,[Margin_PayOff]
      ,[Margin_Over]
      ,[Margin_Increase]
      ,[Margin_Ratio]
      ,[Margin_Offset]
  FROM [dbo].[MARGIN]
  WHERE stock = \'{}\' ORDER BY date DESC"""
  
margin_df = pd.read_sql_query( cmd.format( query_num ), engine )

color = np.array( ['rgb(255,255,255)'] * margin_df[ 'Financing_Increase' ].shape[ 0 ] )
color[ margin_df[ 'Financing_Increase' ] < 0 ] = '#5fba7d'
color[ margin_df[ 'Financing_Increase' ] > 0 ] = '#d65f5f'

trace1 = go.Bar(
    
    x = margin_df[ 'date' ],
    y = margin_df[ 'Financing_Increase' ],
    
    name = '融資差額',
    
    marker=dict(
        color= color.tolist( ),
        line = dict(
            color = color.tolist( ),
            width=1,
        )
    ),
    
    opacity = 0.6
)

trace2 = go.Scatter(
    
    x = margin_df[ 'date' ],
    y = margin_df[ 'Financing_Over' ],
    mode = 'lines',
    name = '融資張數',
    line = dict( width = 1 ),
    yaxis='y2'
)

data = [ trace1, trace2 ]

layout = go.Layout(
    
    title='融資',
    
    yaxis=dict(
        title='單日買量'
    ),
    
    yaxis2 = dict(
        
        title='累計買賣量',
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

fig = go.Figure(data=data, layout=layout)
py.offline.iplot( fig, filename='ohlc_datetime' )

# margin_df.head()
# Out:
# <div id="a5e15fc5-ccbf-4c2e-bdad-4a0e3df72eb5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a5e15fc5-ccbf-4c2e-bdad-4a0e3df72eb5", [{"marker": {"color": ["#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "rgb(255,255,255)", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d"], "line": {"color": ["#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba ...

# %%
color = np.array(['rgb(255,255,255)'] * margin_df['Margin_Increase'].shape[0])
color[margin_df['Margin_Increase'] < 0] = '#5fba7d'
color[margin_df['Margin_Increase'] > 0] = '#d65f5f'

trace1 = go.Bar(
    x=margin_df['date'],
    y=margin_df['Margin_Increase'],
    name='融卷差額',
    marker=dict(
        color=color.tolist(), line=dict(
            color=color.tolist(),
            width=1,
        )),
    opacity=0.6)

trace2 = go.Scatter(
    x=margin_df['date'],
    y=margin_df['Margin_Over'],
    mode='lines',
    name='融卷張數',
    line=dict(width=1),
    yaxis='y2')

data = [trace1, trace2]

layout = go.Layout(
    title='融卷',
    yaxis=dict(title='單日賣量'),
    yaxis2=dict(
        title='累計買賣量',
        titlefont=dict(color='rgb(148, 103, 189)'),
        tickfont=dict(color='rgb(148, 103, 189)'),
        overlaying='y',
        side='right'))

fig = go.Figure(data=data, layout=layout)

py.offline.iplot(fig, filename='ohlc_datetime')
# Out:
# <div id="9f63becd-d93a-4a48-b7a9-c8e2ae89821a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9f63becd-d93a-4a48-b7a9-c8e2ae89821a", [{"marker": {"color": ["#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "rgb(255,255,255)", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "rgb(255,255,255)", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "rgb(255,255,255)", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "rgb(255,255,255)", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "rgb(255,255,255)", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d"], "line": {"color": ["#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "rgb(255,255,255)", "rgb(255,255,255)", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#5f ...

# %%
cmd = """SELECT [stock]
      ,[date]
      ,[lend_over]
      ,[lend_chang]
      ,[lend_return]
      ,[lend_diff]
      ,[sell_over]
      ,[sell_day]
      ,[sell_day_return]
      ,[sell_day_diff]
      ,[sell_day_limit]
  FROM [dbo].[LEND]
  WHERE stock = \'{}\' ORDER BY date DESC"""
  
lend_df = pd.read_sql_query( cmd.format( query_num ), engine )

lend_df.head().style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aa" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >stock</th>
#         <th class="col_heading level0 col1" >date</th>
#         <th class="col_heading level0 col2" >lend_over</th>
#         <th class="col_heading level0 col3" >lend_chang</th>
#         <th class="col_heading level0 col4" >lend_return</th>
#         <th class="col_heading level0 col5" >lend_diff</th>
#         <th class="col_heading level0 col6" >sell_over</th>
#         <th class="col_heading level0 col7" >sell_day</th>
#         <th class="col_heading level0 col8" >sell_day_return</th>
#         <th class="col_heading level0 col9" >sell_day_diff</th>
#         <th class="col_heading level0 col10" >sell_day_limit</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aalevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col0" class="data row0 col0" >2330</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col1" class="data row0 col1" >2018-03-28</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col2" class="data row0 col2" >360805000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col3" class="data row0 col3" >1633000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col4" class="data row0 col4" >4680000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col5" class="data row0 col5" >-3047000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col6" class="data row0 col6" >16736000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col7" class="data row0 col7" >454000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col8" class="data row0 col8" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col9" class="data row0 col9" >454000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow0_col10" class="data row0 col10" >11981284</td>
#     </tr>    <tr>
#         <th id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aalevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col0" class="data row1 col0" >2330</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col1" class="data row1 col1" >2018-03-27</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col2" class="data row1 col2" >363852000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col3" class="data row1 col3" >8047000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col4" class="data row1 col4" >3051000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col5" class="data row1 col5" >4996000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col6" class="data row1 col6" >16282000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col7" class="data row1 col7" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col8" class="data row1 col8" >2546000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col9" class="data row1 col9" >-2546000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow1_col10" class="data row1 col10" >12147583</td>
#     </tr>    <tr>
#         <th id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aalevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col0" class="data row2 col0" >2330</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col1" class="data row2 col1" >2018-03-26</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col2" class="data row2 col2" >358856000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col3" class="data row2 col3" >8123000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col4" class="data row2 col4" >2835000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col5" class="data row2 col5" >5288000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col6" class="data row2 col6" >18828000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col7" class="data row2 col7" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col8" class="data row2 col8" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col9" class="data row2 col9" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow2_col10" class="data row2 col10" >12093657</td>
#     </tr>    <tr>
#         <th id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aalevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col0" class="data row3 col0" >2330</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col1" class="data row3 col1" >2018-03-23</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col2" class="data row3 col2" >353568000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col3" class="data row3 col3" >26749000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col4" class="data row3 col4" >13700000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col5" class="data row3 col5" >13049000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col6" class="data row3 col6" >18828000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col7" class="data row3 col7" >93000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col8" class="data row3 col8" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col9" class="data row3 col9" >93000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow3_col10" class="data row3 col10" >12007782</td>
#     </tr>    <tr>
#         <th id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aalevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col0" class="data row4 col0" >2330</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col1" class="data row4 col1" >2018-03-22</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col2" class="data row4 col2" >340519000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col3" class="data row4 col3" >11047000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col4" class="data row4 col4" >50000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col5" class="data row4 col5" >10997000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col6" class="data row4 col6" >18735000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col7" class="data row4 col7" >868000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col8" class="data row4 col8" >0</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col9" class="data row4 col9" >868000</td>
#         <td id="T_3e6fea6e_5be5_11e8_aa68_54e1ad3162aarow4_col10" class="data row4 col10" >11936116</td>
#     </tr></tbody>
# </table>

# %%
# u'當月營收', 
# u'上月營收', 
# u'去年當月營收', 
# u'上月比較增減(%)', 
# u'去年同月增減(%)', 
# u'當月累計營收', 
# u'去年累計營收', 
# u'前期比較增減(%)' 

cmd = """SELECT [stock]
      ,[date]
      ,[Month_Revenue]
      ,[Last_Month_Revenue]
      ,[Last_Year_Revenue]
      ,[Last_Month_Ratio]
      ,[Last_Year_Ration]
      ,[Month_Acc_Revenue]
      ,[Last_Year_Acc_Revenue]
      ,[ration]  
  FROM [dbo].[REVENUE]
  WHERE stock = \'{}\' ORDER BY date DESC"""
  
revenue_df = pd.read_sql_query( cmd.format( query_num ), engine )

# revenue_df.head()

# %%
fig = tls.make_subplots( rows=8, cols=1, shared_xaxes=False )
#                         subplot_titles=( '集中度', 'K線', '主力買賣超', '主力買賣超') )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Month_Revenue'], 
                   'type': 'scatter', 
                   'name': '當月營收' }, 1, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Last_Month_Revenue'], 
                   'type': 'scatter', 
                   'name': '上月營收' }, 2, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Last_Year_Revenue'], 
                   'type': 'scatter', 
                   'name': '去年當月營收' }, 3, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Last_Month_Ratio'], 
                   'type': 'scatter', 
                   'name': '上月比較增減%' }, 4, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Last_Year_Ration'], 
                   'type': 'scatter', 
                   'name': '去年同月增減%' }, 5, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Month_Acc_Revenue'], 
                   'type': 'scatter', 
                   'name': '當月累計營收' }, 6, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['Last_Year_Acc_Revenue'], 
                   'type': 'scatter', 
                   'name': '去年累計營收' }, 7, 1 )

fig.append_trace( {'x': revenue_df['date'], 
                   'y': revenue_df['ration'], 
                   'type': 'scatter', 
                   'name': '前期比較增減' }, 8, 1 )

py.offline.iplot( fig, filename= '月營收' )
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x2,y2 ]
# [ (3,1) x3,y3 ]
# [ (4,1) x4,y4 ]
# [ (5,1) x5,y5 ]
# [ (6,1) x6,y6 ]
# [ (7,1) x7,y7 ]
# [ (8,1) x8,y8 ]
# <div id="390084d7-a3e5-412d-89fb-e067d3b1d899" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
0, 93153310.0, 94519722.0, 88578988.0, 91917167.0, 71611190.0, 84187305.0, 72795974.0, 56871933.0, 85875181.0, 71422961.0, 76616258.0, 78112022.0, 93029912.0, 91085318.0, 89702807.0, 94311424.0, 76391654.0, 81390752.0, 73575784.0, 66843310.0, 73088805.0, 59551321.0, 70855235.0, 58347005.0, 63428163.0, 81743395.0, 64514083.0, 67038016.0, 80952810.0, 59955479.0, 70154763.0, 75329510.0, 72269001.0, 62645075.0, 87120068.0, 69510190.0, 72274532.0, 80736353.0, 74846313.0, 69278551.0, 64924870.0, 60343956.0, 60789137.0, 61887391.0, 49956128.0, 46829051.0, 51429993.0, 49681037.0, 44329997.0, 51794813.0, 55382473.0, 55091177.0, 52103384.0, 54027749.0, 51787926.0, 50070645.0, 44134225.0, 41182084.0, 47438687.0, null, 43644278.0, 49282571.0, 42816800.0, 48896013.0, 47924170.0, 42869733.0, 43623222.0, 40007591.0, 36611146.0, 33584499.0, 34053091.0, 30566947.0, 35218771.0, 37246661.0, 32860849.0, 37041705.0, 34916788.0, 35653939.0, 35960997.0,  ...

# %%
path = r'C:\workspace\stock\01_Day process\券商分點\籌碼集中暫存.csv'

csv_df = pd.read_csv(
    path,
    sep=',',
    encoding='utf8',
    false_values='NA',
    dtype={
        '股號': str,
        '日期': str
    },
)

query_num = '2317'

filename = '{}_籌碼集中.html'.format(query_num)

csv_df = csv_df[ csv_df['股號'] == query_num ]

csv_df = csv_df[ [ '日期', '收盤', '01天集中%', '03天集中%', '05天集中%', 
                   '10天集中%', '20天集中%', '60天集中%' ] ]

csv_df = csv_df[ 0:60 ] 

csv_df = csv_df.set_index('日期')

csv_df.style.bar( subset=[ '01天集中%', '03天集中%', 
                           '05天集中%', '10天集中%', '20天集中%',
                           '60天集中%' ],
                  align='zero', 
                  color=[ '#5fba7d', '#d65f5f' ],
                  width=50 )
# Out:
# <style  type="text/css" >
#     #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 59.4%, transparent 59.4%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 64.5%, transparent 64.5%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 62.3%, transparent 62.3%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 50.0%, transparent 50.0%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 39.4%, #5fba7d 39.4%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.8%, #5fba7d 27.8%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 63.4%, transparent 63.4%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 57.2%, transparent 57.2%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 55.1%, transparent 55.1%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 42.3%, #5fba7d 42.3%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 34.2%, #5fba7d 34.2%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 25.5%, #5fba7d 25.5%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 57.7%, transparent 57.7%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 49.5%, #5fba7d 49.5%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.3%, #5fba7d 45.3%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 36.6%, #5fba7d 36.6%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.2%, #5fba7d 30.2%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 25.0%, #5fba7d 25.0%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 39.7%, #5fba7d 39.7%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.9%, #5fba7d 44.9%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.2%, #5fba7d 33.2%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.8%, #5fba7d 33.8%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 28.8%, #5fba7d 28.8%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent nan%, #5fba7d nan%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50%, #d65f5f 50%, #d65f5f 54.2%, transparent 54.2%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.9%, #5fba7d 45.9%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.6%, #5fba7d 31.6%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #5fba7d 33.4%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 28.0%, #5fba7d 28.0%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent nan%, #5fba7d nan%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.4%, #5fba7d 40.4%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.0%, #5fba7d 27.0%, #5fba7d 50%, transparent 50%);
#         }    #T_3e997606_5be5_11e8_8e1e_54e1ad3162aarow5_col3 {
#             width:  10em;
#              height:  80%

# %%
path = r'C:\workspace\stock\01_Day process\券商分點\籌碼集中暫存.csv'

csv_df = pd.read_csv(
    path,
    sep=',',
    encoding='utf8',
    false_values='NA',
    dtype={
        '股號': str,
        '日期': str
    },
)

query_num = '2317'

filename = '{}_籌碼集中.html'.format(query_num)

csv_df = csv_df[csv_df['股號'] == query_num]

csv_df = csv_df[[
    '日期', '收盤', '01天集中%', '03天集中%', '05天集中%', '10天集中%', '20天集中%', '60天集中%'
]]

csv_df = csv_df[0:60]

csv_df = csv_df.set_index('日期')


def high_vals(val, hi, mid, low):

    if val >= hi:
        return 'background-color: #d65f5f'
    elif val >= mid:
        return 'background-color: rgb( 250, 215, 80 )'
    elif val >= low:
        return 'background-color: rgb( 158, 202, 225 )'
    else:
        return ''


obj = csv_df.style.applymap(
    high_vals, subset=['01天集中%'], hi=20, mid=15, low=12)

obj.applymap(high_vals, subset=['03天集中%'], hi=15, mid=12, low=10)

obj.applymap(high_vals, subset=['05天集中%'], hi=15, mid=12, low=10)

obj.applymap(high_vals, subset=['10天集中%'], hi=12, mid=10, low=8)

obj.applymap(high_vals, subset=['20天集中%'], hi=10, mid=8, low=6)

obj.applymap(high_vals, subset=['60天集中%'], hi=8, mid=6, low=100)
# Out:
# <style  type="text/css" >
#     #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col1 {
#             background-color:  #d65f5f;
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col2 {
#             background-color:  #d65f5f;
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col3 {
#             background-color:  #d65f5f;
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col1 {
#             background-color:  #d65f5f;
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col2 {
#             background-color:  rgb( 250, 215, 80 );
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col1 {
#             background-color:  rgb( 250, 215, 80 );
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow32_col1 {
#             background-color:  rgb( 158, 202, 225 );
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow39_col2 {
#             background-color:  rgb( 158, 202, 225 );
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow40_col1 {
#             background-color:  #d65f5f;
#         }    #T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow40_col2 {
#             background-color:  rgb( 158, 202, 225 );
#         }</style>
# <table id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aa" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >收盤</th>
#         <th class="col_heading level0 col1" >01天集中%</th>
#         <th class="col_heading level0 col2" >03天集中%</th>
#         <th class="col_heading level0 col3" >05天集中%</th>
#         <th class="col_heading level0 col4" >10天集中%</th>
#         <th class="col_heading level0 col5" >20天集中%</th>
#         <th class="col_heading level0 col6" >60天集中%</th>
#     </tr>    <tr>
#         <th class="index_name level0" >日期</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row0" class="row_heading level0 row0" >2018/05/14</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col0" class="data row0 col0" >89</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col1" class="data row0 col1" >22.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col2" class="data row0 col2" >24.5</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col3" class="data row0 col3" >17.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col4" class="data row0 col4" >-0</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col5" class="data row0 col5" >-11.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow0_col6" class="data row0 col6" >-17.7</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row1" class="row_heading level0 row1" >2018/05/11</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col0" class="data row1 col0" >85</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col1" class="data row1 col1" >32.2</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col2" class="data row1 col2" >12.1</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col3" class="data row1 col3" >7.4</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col4" class="data row1 col4" >-10.1</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col5" class="data row1 col5" >-17.2</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow1_col6" class="data row1 col6" >-19.5</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row2" class="row_heading level0 row2" >2018/05/10</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col0" class="data row2 col0" >82.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col1" class="data row2 col1" >18.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col2" class="data row2 col2" >-0.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col3" class="data row2 col3" >-6.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col4" class="data row2 col4" >-17.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col5" class="data row2 col5" >-21.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow2_col6" class="data row2 col6" >-19.9</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row3" class="row_heading level0 row3" >2018/05/09</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col0" class="data row3 col0" >81.8</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col1" class="data row3 col1" >-24.7</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col2" class="data row3 col2" >-8.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col3" class="data row3 col3" >-24.5</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col4" class="data row3 col4" >-21.3</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col5" class="data row3 col5" >-23.2</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow3_col6" class="data row3 col6" >nan</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row4" class="row_heading level0 row4" >2018/05/08</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col0" class="data row4 col0" >82.6</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col1" class="data row4 col1" >10</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col2" class="data row4 col2" >-7</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col3" class="data row4 col3" >-26.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col4" class="data row4 col4" >-21.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col5" class="data row4 col5" >-24</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow4_col6" class="data row4 col6" >nan</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row5" class="row_heading level0 row5" >2018/05/04</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col0" class="data row5 col0" >80.4</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col1" class="data row5 col1" >-23.1</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col2" class="data row5 col2" >-38.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col3" class="data row5 col3" >-28.4</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col4" class="data row5 col4" >-26.8</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col5" class="data row5 col5" >-26.2</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow5_col6" class="data row5 col6" >nan</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row6" class="row_heading level0 row6" >2018/05/03</th>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col0" class="data row6 col0" >80.1</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col1" class="data row6 col1" >-52.5</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col2" class="data row6 col2" >-33.2</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col3" class="data row6 col3" >-26.7</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col4" class="data row6 col4" >-23.9</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col5" class="data row6 col5" >-27.3</td>
#         <td id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aarow6_col6" class="data row6 col6" >nan</td>
#     </tr>    <tr>
#         <th id="T_4feeddde_5be7_11e8_baa3_54e1ad3162aalevel0_row7" class="row_heading level0 row7" >2018/04/30</th>
#         <td id="T_4feedd

# %%
path = r'C:\workspace\stock\01_Day process\券商分點\籌碼集中暫存.csv'

csv_df = pd.read_csv(
    path,
    sep=',',
    encoding='utf8',
    false_values='NA',
    dtype={
        '股號': str,
        '日期': str
    },
)

filename = '{}_籌碼集中.html'.format(query_num)

csv_df = csv_df[csv_df['股號'] == query_num]
csv_df = csv_df[::-1]

# hover_text = df.apply( lambda r: '<br>'.join( [ '{}: {}'.format( c, r[c] )
#                                             for c in df.columns ] ), axis=1 )

fig = tls.make_subplots(rows=2, cols=1, shared_xaxes=True)
#                         subplot_titles=( '集中度', 'K線', '主力買賣超', '主力買賣超') )

color = np.array(['rgb(255,255,255)'] * csv_df['01天主力買賣超(張)'].shape[0])
color[csv_df['01天主力買賣超(張)'] < 0] = '#5fba7d'
color[csv_df['01天主力買賣超(張)'] > 0] = '#d65f5f'

fig.append_trace({
    'x': csv_df['日期'],
    'y': csv_df['01天集中%'],
    'type': 'scatter',
    'name': '01天集中%'
}, 1, 1)

fig.append_trace({
    'x': csv_df['日期'],
    'y': csv_df['05天集中%'],
    'type': 'scatter',
    'name': '05天集中%'
}, 1, 1)

fig.append_trace(
    {
        'x': csv_df['日期'],
        'y': csv_df['01天主力買賣超(張)'],
        'type': 'bar',
        'name': '張',
        'marker': dict(color=color.tolist()),
    },
    2,
    1)

py.offline.iplot(fig, filename=filename)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# <div id="daf58abc-0af0-442a-bf17-bc15e4e31077" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("daf58abc-0af0-442a-bf17-bc15e4e31077", [{"xaxis": "x1", "y": [-9.9, -19.6, -1.7, -6.1, 10.4, -12.4, -5.2, -3.8, -4.1, -7.4, 6.8, -7.7, -8.3, 9.4, -23.8, -10.6, 4.1, 7.7, 4.4, -3.6, 8.5, -7.6, 14.1, -10.1, 16.6, -17.8, -6.0, 3.9, 8.3, -2.3, 3.5, -10.2, 9.1, -7.2, 15.8, 10.4, -5.1, -10.6, 8.5, 5.5, 5.7, 7.5, -16.7], "type": "scatter", "x": ["2018/03/08", "2018/03/09", "2018/03/12", "2018/03/13", "2018/03/14", "2018/03/15", "2018/03/16", "2018/03/19", "2018/03/20", "2018/03/21", "2018/03/22", "2018/03/23", "2018/03/26", "2018/03/27", "2018/03/28", "2018/03/29", "2018/03/30", "2018/03/31", "2018/04/02", "2018/04/03", "2018/04/09", "2018/04/10", "2018/04/11", "2018/04/12", "2018/04/13", "2018/04/16", "2018/04/17", "2018/04/18", "2018/04/19", "2018/04/20", "2018/04/23", "2018/04/24", "2018/04/25", "2018/04/26", "2018/04/27", "2018/04/30", "2018/05/03", "2018/05/04", "2018/05/08", "2018/05/09", "2018/05/10", "2018/05/11", "2018/05/14"], "name": "01\u5929\u96c6\u4e2d%", "yaxis": "y1"}, {"xaxis": "x1", "y": [3.3, -4.2, -6.6, -8.0, -3.4, -3.5, 1.1, 1.9, 3.9, -1.6, -0.4, -2.1, -2.4, -1.1, -0.0, -1.6, -0.3, 4.1, 3.0, 2.7, 4.8, 3.3, 3.4, 1.5, 4.1, -1.2, 1.3, -0.9, 2.6, -0.1, 2.1, -1.0, 0.1, -1.3, -0.5, -0.4, 0.3, 0.5, -1.6, 2.9, 3.8, 5.2, -3.6], "type": "scatter", "x": ["2018/03/08", "2018/03/09", "2018/03/12", "2018/03/13", "2018/03/14", "2018/03/15", "2018/03/16", "2018/03/19", "2018/03/20", "2018/03/21", "2018/03/22", "2018/03/23", "2018/03/26", "2018/03/27", "2018/03/28", "2018/03/29", "2018/03/30", "2018/03/31", "2018/04/02", "2018/04/03", "2018/04/09", "2018/04/10", "2018/04/11", "2018/04/12", "2018/04/13", "2018/04/16", "2018/04/17", "2018/04/18", "2018/04/19", "2018/04/20", "2018/04/23", "2018/04/24", "2018/04/25", "2018/04/26", "2018/04/27", "2018/04/30", "2018/05/03", "2018/05/04", "2018/05/08", "2018/05/09", "2018/05/10", "2018/05/11", "2018/05/14"], "name": "05\u5929\u96c6\u4e2d%", "yaxis": "y1"}, {"xaxis": "x1", "marker": {"color": ["#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#5fba7d", "#d65f5f", "#d65f5f", "#5fba7d", "#5fba7d", "#d65f5f", "#d65f5f", "#d65f5f", "#d65f5f", "#5fba7d"]}, "type": "bar", "x": ["2018/03/08", "2018/03/09", "2018/03/12", "2018/03/13", "2018/03/14", "2018/03/15", "2018/03/16", "2018/03/19", "2018/03/20", "2018/03/21", "2018/03/22", "2018/03/23", "2018/03/26", "2018/03/27", "2018/03/28", "2018/03/29", "2018/03/30", "2018/03/31", "2018/04/02", "2018/04/03", "2018/04/09", "2018/04/10", "2018/04/11", "2018/04/12", "2018/04/13", "2018/04/16", "2018/04/17", "2018/04/18", "2018/04/19", "2018/04/20", "2018/04/23", "2018/04/24", "2018/04/25", "2018/04/26", "2018/04/27", "2018/04/30", "2018/05/03", "2018/05/04", "2018/05/08", "2018/05/09", "2018/05/10", "2018/05/11", "2018/05/14"], "name": "\u5f35", "yaxis": "y2", "y": [-1644.0, -4460.0, -266.0, -560.0, 2938.0, -1916.0, -381.0, -386.0, -416.0, -867.0, 842.0, -1119.0, -1760.0, 1114.0, -1577.0, -586.0, 680.0, 1957.0, 1326.0, -573.0, 2949.0, -2428.0, 2802.0, -1257.0, 1690.0, -1769.0, -808.0, 496.0, 2593.0, -553.0, 1157.0, -3790.0, 1956.0, -1631.0, 2201.0, 2939.0, -616.0, -1281.0, 692.0, 626.0, 1152.0, 1013.0, -6394.0]}], {"xaxis1": {"domain": [0.0, 1.0], "anchor": "y2"}, "yaxis1": {"domain": [0.575, 1.0], "position": 0.0, "anchor": "free"}, "yaxis2": {"domain": [0.0, 0.425], "anchor": "x1"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
cmd = """SELECT [stock]
      ,[date]
      ,[Share_Rating_People_1_999]
      ,[Share_Rating_Unit_1_999]
      ,[Share_Rating_Proportion_1_999]
      ,[Share_Rating_People_1000_5000]
      ,[Share_Rating_Unit_1000_5000]
      ,[Share_Rating_Proportion_1000_5000]
      ,[Share_Rating_People_5001_10000]
      ,[Share_Rating_Unit_5001_10000]
      ,[Share_Rating_Proportion_5001_10000]
      ,[Share_Rating_People_10001_15000]
      ,[Share_Rating_Unit_10001_15000]
      ,[Share_Rating_Proportion_10001_15000]
      ,[Share_Rating_People_15001_20000]
      ,[Share_Rating_Unit_15001_20000]
      ,[Share_Rating_Proportion_15001_20000]
      ,[Share_Rating_People_20001_30000]
      ,[Share_Rating_Unit_20001_30000]
      ,[Share_Rating_Proportion_20001_30000]
      ,[Share_Rating_People_30001_40000]
      ,[Share_Rating_Unit_30001_40000]
      ,[Share_Rating_Proportion_30001_40000]
      ,[Share_Rating_People_40001_50000]
      ,[Share_Rating_Unit_40001_50000]
      ,[Share_Rating_Proportion_40001_50000]
      ,[Share_Rating_People_50001_100000]
      ,[Share_Rating_Unit_50001_100000]
      ,[Share_Rating_Proportion_50001_100000]
      ,[Share_Rating_People_100001_200000]
      ,[Share_Rating_Unit_100001_200000]
      ,[Share_Rating_Proportion_100001_200000]
      ,[Share_Rating_People_200001_400000]
      ,[Share_Rating_Unit_200001_400000]
      ,[Share_Rating_Proportion_200001_400000]
      ,[Share_Rating_People_400001_600000]
      ,[Share_Rating_Unit_400001_600000]
      ,[Share_Rating_Proportion_400001_600000]
      ,[Share_Rating_People_600001_800000]
      ,[Share_Rating_Unit_600001_800000]
      ,[Share_Rating_Proportion_600001_800000]
      ,[Share_Rating_People_800001_1000000]
      ,[Share_Rating_Unit_800001_1000000]
      ,[Share_Rating_Proportion_800001_1000000]
      ,[Share_Rating_People_Up_1000001]
      ,[Share_Rating_Unit_Up_1000001]
      ,[Share_Rating_Proportion_Up_1000001]
  FROM [dbo].[TDCC]
  WHERE stock = \'{}\' ORDER BY date DESC"""

tdcc_df = pd.read_sql_query(cmd.format(query_num), engine)

tdcc_df.head()

tdcc_df[ '散戶持股比例100張以下' ] = tdcc_df[ 'Share_Rating_Proportion_1_999' ] + \
tdcc_df['Share_Rating_Proportion_1000_5000']  + \
tdcc_df['Share_Rating_Proportion_5001_10000'] + \
tdcc_df['Share_Rating_Proportion_10001_15000'] + \
tdcc_df['Share_Rating_Proportion_15001_20000'] +\
tdcc_df['Share_Rating_Proportion_20001_30000'] +\
tdcc_df['Share_Rating_Proportion_30001_40000'] +\
tdcc_df['Share_Rating_Proportion_40001_50000'] +\
tdcc_df['Share_Rating_Proportion_50001_100000']

tdcc_df[
    '散戶持股比例200張以下'] = tdcc_df['散戶持股比例100張以下'] + tdcc_df['Share_Rating_Proportion_100001_200000']

tdcc_df['散戶持股比例400張以下'] = tdcc_df['散戶持股比例200張以下'] + \
                                 tdcc_df[ 'Share_Rating_Proportion_200001_400000']

tdcc_df['散戶持股比例600張以下'] = tdcc_df['散戶持股比例400張以下'] + \
                                 tdcc_df[ 'Share_Rating_Proportion_400001_600000']

tdcc_df['散戶持股比例800張以下'] = tdcc_df['散戶持股比例600張以下'] + \
                                 tdcc_df[ 'Share_Rating_Proportion_600001_800000']

tdcc_df['大戶持股比例400張以上'] = tdcc_df['Share_Rating_Proportion_400001_600000']  + \
tdcc_df['Share_Rating_Proportion_600001_800000']  + \
tdcc_df['Share_Rating_Proportion_800001_1000000'] + \
tdcc_df['Share_Rating_Proportion_Up_1000001']

tdcc_df['大戶持股比例600張以上'] = tdcc_df['大戶持股比例400張以上'] - \
                                  tdcc_df['Share_Rating_Proportion_400001_600000']

tdcc_df['大戶持股比例800張以上'] = tdcc_df['大戶持股比例600張以上'] - \
                                 tdcc_df['Share_Rating_Proportion_600001_800000']

tdcc_df['大戶持股比例1000張以上'] = tdcc_df['大戶持股比例800張以上'] - \
                                 tdcc_df['Share_Rating_Proportion_800001_1000000']

tdcc_df['date'] = pd.to_datetime(tdcc_df['date'])

tdcc_df = pd.merge(tdcc_df, tech_d_df, on='date', how='right')

tdcc_df = tdcc_df[tdcc_df['大戶持股比例1000張以上'].notnull()]

# %%
trace1 = go.Scatter(x=tdcc_df['date'], y=tdcc_df['大戶持股比例1000張以上'], name='大戶持股')

trace2 = go.Scatter(
    x=tdcc_df['date'], y=tdcc_df['散戶持股比例400張以下'], name='散戶持股', yaxis='y2')

trace3 = go.Scatter(
    x=tdcc_df['date'], y=tdcc_df['close_price'], name='股價', yaxis='y3')

data = [trace1, trace2, trace3]

layout = go.Layout(
    title='{}持股比例'.format(query_num),
    width=800,
    xaxis=dict(domain=[0.09, 1]),
    yaxis=dict(
        title='比例1000張以上',
        titlefont=dict(color='#1f77b4'),
        tickfont=dict(color='#1f77b4')),
    yaxis2=dict(
        title='比例400張以下',
        titlefont=dict(color='#ff7f0e'),
        tickfont=dict(color='#ff7f0e'),
        anchor='free',
        overlaying='y',
        side='left',
        position=0),
    yaxis3=dict(
        title='股價',
        titlefont=dict(color='#d62728'),
        tickfont=dict(color='#d62728'),
        overlaying='y',
        anchor='x',
        side='right'),
)

fig = go.Figure(data=data, layout=layout)

py.offline.iplot(fig, filename='{} 持股比例'.format(query_num))

# tech_d_df.head( 30 )
# Out:
# <div id="e818b3fd-b8c7-400c-aab1-01e31bf7cf0f" style="height: 525px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("